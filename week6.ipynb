# %%
import pandas as pd

# %%
#strings
country=['India','pakistan','america','nepal','shrilanka']
pd.Series(country)#Series is class of pandas
# Out:
# 0        India
# 1     pakistan
# 2      america
# 3        nepal
# 4    shrilanka
# dtype: object

# %%
#integers
runs=[12,23,34,45,67]
pd.Series(runs)
# Out:
# 0    12
# 1    23
# 2    34
# 3    45
# 4    67
# dtype: int64

# %%
#custome index
marks=[67,68,60,78]
sub=['math','physcis','chemistry','English']
pd.Series(marks)
# Out:
# 0    67
# 1    68
# 2    60
# 3    78
# dtype: int64

# %%
pd.Series(marks,index=sub)
# Out:
# math         67
# physcis      68
# chemistry    60
# English      78
# dtype: int64

# %%
#setting a name 
pd.Series(marks,index=sub,name='Utkarsh')
# Out:
# math         67
# physcis      68
# chemistry    60
# English      78
# Name: Utkarsh, dtype: int64

# %%
marks=pd.Series(marks,index=sub,name='Utkarsh')

# %%
#series fro dictionary(automatically name become indwx and value is become value.)
marks={
    'maths':67,
    'english':57,
    'science':89,
'hindi':100
 
}
marks_series=pd.Series(marks,name= "Utkarsh")
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Utkarsh, dtype: int64

# %%
#size
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# 'Utkarsh'

# %%
#is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,2,343,343,2,4,5,24,35]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #index
# ----> 2 marks_series.index
#
# NameError: name 'marks_series' is not defined

# %%
#values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# Series using read_csv

# %%
#read csv file 
df=pd.read_csv('bollywood.csv')
df
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#(squeeze=True) is used to convert Datarame inti Series.
pd.read_csv('bollywood.csv')
s=df.squeeze('columns')

# %%
s
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s=df['movie']

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df=pd.read_csv('bollywood.csv',index_col='movie')

# %%
df
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
pandas.core.frame.DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pandas.core.frame.DataFrame
#
# NameError: name 'pandas' is not defined

# %%
df

# %%
type(df)

# %%
s=df.stack()

# %%
type(s)

# %%
type(df)

# %%
df.head()#top 5 rows

# %%
df.tail()#bottom  5 rows

# %%
df.sample()# random onlu one rows shows

# %%
df.sample(5)#used when data is biased

# %%
#value_count(describe the frequency)

# %%
df.value_counts()

# %%
#df.sort_values()by descendingfor (ascending+False)

# %%
df.sort_index(inplace=True)

# %%
df

# %%
#series maths methods

# %%
import pandas as pd

# %%
df1=pd.read_csv('subs.csv')

# %%
df1.min()

# %%
df1.max()

# %%
df1.describe()#it provide summary of whole dataset

# %%
#integer indexing
x=pd.Series([12,13,14,35,45,57])
x[0]

# %%
#negative indexing(series does not  work on negative indexing)
#when custom index is string then it work and when it is integer not working.

# %%
#slicing(at time we can fetch more element)
df1[-5:]

# %%
#fancy indexing
#df1[[1,3,4,5]]

# %%
#indexing with label -> fancy indexing

# %% [markdown]
# Editing series

# %%
#using index label
marks_series[1]=200;
# Out:
# C:\Users\rashi\AppData\Local\Temp\ipykernel_2744\390979758.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=200;

# %%
marks_series
# Out:
# maths       67
# english    200
# science     89
# hindi      100
# Name: Utkarsh, dtype: int64

# %%
marks_series['c+']=3000

# %%
marks_series
# Out:
# maths        67
# english     200
# science      89
# hindi       100
# c+         3000
# Name: Utkarsh, dtype: int64

# %%
#slicing
runs_ser=[100,350]
runs_ser
# Out:
# [100, 350]

# %%
#fancy indexing
runs_ser

# %%
#membership operator works on only key not value

# %%
#Arthmetic operator(broadcasting and it add 100 in all values)
100+marks_series
# Out:
# maths      167
# english    157
# science    189
# hindi      200
# Name: Utkarsh, dtype: int64

# %%
#relational operator

# %%
#astype is used to change data type.
import sys
sys.getsizeof(marks)
# Out:
# 88

# %%
#marks.astype('int16')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 marks.astype('int16')
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
#between is used to find the value in particular rage and return as boolean value.
#vk[vk.between(51,99)].size

# %%
#clip is used to set value in particular range like that we want set value in particular range 100 to 200.and less than 100 set to 100 and greater than 200 is set to 200
df1.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
#drop_duplicates is used to remove duplicates value.
temp=pd.Series([1,1,1,2,3,3,4,5,6])
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    3
# 5    3
# 6    4
# 7    5
# 8    6
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 3    2
# 4    3
# 6    4
# 7    5
# 8    6
# dtype: int64

# %%
temp.drop_duplicates(keep='last')#means first will be remove and last remain and  by default keep is first
# Out:
# 2    1
# 3    2
# 5    3
# 6    4
# 7    5
# 8    6
# dtype: int64

# %%
#duplicated ,it tells that value is duplicated or not if value is false means value is not duplicates.
temp.duplicated()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
temp.duplicated().sum()
# Out:
# np.int64(3)

# %%
temp.count()
# Out:
# np.int64(9)

# %%
temp.size
# Out:
# 9

# %%
#marks_series.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 marks_series.isnull().sum()
#
# NameError: name 'marks_series' is not defined

# %%
#dropna() make a  new series from existing dataset and it remove all missing values.

# %%
#fillna() is also make a new dataset from existing dataset and missing value replace by some value.
#temp.fillna(temp.mean())means we want replace missing value by mean of temp.

# %%
#isin(), it return as boolean value. 
#vk.isin([49,45,46])

# %%
#apply , it helps to apply custom logic on datasets
#

# %%
#copy and view

# %%
#when we fetch data through head() and tail() and changes anythings in datasets it directly reflect on data and head()and tail() provide view of dataset
#to avoid these condition we copy function.
