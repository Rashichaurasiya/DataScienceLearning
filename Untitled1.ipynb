# %%
import pandas as pd
import numpy as np

# %%
batsman_run=pd.read_csv(r"C:\Users\rashi\Downloads\batsman_runs_ipl.csv")
batsman_runs_ipl=pd.read_csv(r"C:\Users\rashi\Downloads\batsman_runs_ipl.csv")
ipl_matches=pd.read_csv(r"C:\Users\rashi\Downloads\ipl-matches.csv")
batsman_runs_series=pd.read_csv(r"C:\Users\rashi\Downloads\batsman_runs_series.csv")

# %%
student_data=[[100,80,10],[90,70,7],[120,100,14],[80,50,2]]
df=pd.DataFrame(student_data,columns=['iq','marks','package'])

# %%
df
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# value_counts tells the frequency of rows.
df['marks'].value_counts()
# Out:
# marks
# 80     1
# 70     1
# 100    1
# 50     1
# Name: count, dtype: int64

# %%
ipl_matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#find which player has won most potm -> in files and qualifiers.
ipl_matches[~ipl_matches['MatchNumber'].str.isdigit()]
# Out:
#           ID           City        Date   Season         MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022               Final
# 1    1312199      Ahmedabad  2022-05-27     2022         Qualifier 2
# 2    1312198        Kolkata  2022-05-25     2022          Eliminator
# 3    1312197        Kolkata  2022-05-24     2022         Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021               Final
# 75   1254116        Sharjah  2021-10-13     2021         Qualifier 2
# 76   1254115        Sharjah  2021-10-11     2021          Eliminator
# 77   1254114          Dubai  2021-10-10     2021         Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21               Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21         Qualifier 2
# 136  1237178      Abu Dhabi  2020-11-06  2020/21          Eliminator
# 137  1237177            NaN  2020-11-05  2020/21         Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019               Final
# ...

# %%
ipl_matches[~ipl_matches['MatchNumber'].str.isdigit()].value_counts()
# Out:
# ID       City       Date        Season  MatchNumber  Team1                Team2                  Venue                  TossWinner             TossDecision  SuperOver  WinningTeam            WonBy    Margin  method  Player_of_Match  Team1Players                                                                                                                                         Team2Players                                                                                                                                      Umpire1       Umpire2
# ...

# %%
#Toss decision plot
ipl_matches['TossDecision'].value_counts()
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
ipl_matches['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has played.
ipl_matches['Team2'].value_counts()+ipl_matches['Team1'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
(ipl_matches['Team2'].value_counts()+ipl_matches['Team1'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort_value(series and DataFrame) ->ascending ->na_position ->inplace -> multiple cols

# %%
ipl_matches.sample()
# Out:
#           ID     City        Date Season MatchNumber  \
# 312  1136563  Kolkata  2018-04-08   2018           3
#
#                            Team1                  Team2         Venue  \
# 312  Royal Challengers Bangalore  Kolkata Knight Riders  Eden Gardens
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# 312  Kolkata Knight Riders        field         N  Kolkata Knight Riders
#
#        WonBy  Margin method Player_of_Match  \
# 312  Wickets     4.0    NaN       SP Narine
#
#                                           Team1Players  \
# 312  ['BB McCullum', 'Q de Kock', 'V Kohli', 'AB de...
#
#                                           Team2Players     Umpire1  \
# 312  ['SP Narine', 'CA Lynn', 'RV Uthappa', 'N Rana...  A Deshmukh
#
#            Umpire2
# 312  C Shamshuddin

# %%
ipl_matches.sort_values('City')
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 135  1237180  Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 95   1254098  Abu Dhabi  2021-09-26     2021           38
# 533   729315  Abu Dhabi  2014-04-29     2014           19
# 181  1216503  Abu Dhabi  2020-10-01  2020/21           13
# 92   1254099  Abu Dhabi  2021-09-28     2021           42
# ..       ...        ...         ...      ...          ...
# 543   729295        NaN  2014-04-22     2014            9
# 545   729291        NaN  2014-04-20     2014            7
# 546   729289        NaN  2014-04-19     2014            6
# 547   729287        NaN  2014-04-19     2014            5
# 550   729281        NaN  2014-04-17     2014            2
#
#                            Team1                        Team2  \
# 135               Delhi Capitals          Sunrisers Hyderabad
# 95         Kolkata Knight Riders          Chennai Super Kings
# 533        Kolkata Knight Riders             Rajasthan Royals
# ...

# %%
ipl_matches.sort_values('WinningTeam')
# Out:
#           ID       City        Date   Season MatchNumber  \
# 712   501261    Chennai  2011-05-18     2011          64
# 95   1254098  Abu Dhabi  2021-09-26     2021          38
# 840   392234     Durban  2009-05-20     2009          54
# 526   733981      Delhi  2014-05-05     2014          26
# 176  1216513        NaN  2020-10-04  2020/21          18
# ..       ...        ...         ...      ...         ...
# 291  1136583     Mumbai  2018-04-24     2018          23
# 205  1178424  Bengaluru  2019-04-30     2019          49
# 437   829813  Bangalore  2015-05-17     2015          55
# 464   829763  Bangalore  2015-04-29     2015          29
# 708   501265      Delhi  2011-05-21     2011          68
#
#                            Team1                 Team2  \
# 712          Chennai Super Kings  Kochi Tuskers Kerala
# 95         Kolkata Knight Riders   Chennai Super Kings
# 840          Chennai Super Kings       Kings XI Punjab
# ...

# %%
students=pd.DataFrame(
{
'name':['nitish','ankit','rupesh', np.nan,'mrityunjay',np.nan,'rishabh',np.nan ,'aditya',np.nan],

'college':['bit','iit','vit',np.nan,np.nan,'visi','ssit',np.nan,np.nan,'git'],
'branch':['bio','it','me','eee','civ','cse',np.nan,'ce','cse',np.nan],
    'cgpa':[7.40,8.25,5.60,6.66,7.4,6.41,np.nan,9,10,np.nan],
    'package':[4,5,6,np.nan,6,7,8,0,np.nan,np.nan]
}   
)

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#To show missing value on top we use (columns,na_position parameter='first')
#ydefault value is False
students.sort_values('name',na_position='first',ascending=False)
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    eee   6.66      NaN
# 5         NaN    visi    cse   6.41      7.0
# 7         NaN     NaN     ce   9.00      0.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit     me   5.60      6.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 0      nitish     bit    bio   7.40      4.0
# 4  mrityunjay     NaN    civ   7.40      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    cse  10.00      NaN

# %%
movies1=pd.read_csv('bollywood.csv')
movies1
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
movies=pd.read_csv(r"C:\Users\rashi\Downloads\movies.csv")
movies.sample()
# Out:
#           title_x    imdb_id  \
# 107  Hope Aur Hum  tt8324474
#
#                                            poster_path  \
# 107  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link       title_y original_title  \
# 107  https://en.wikipedia.org/wiki/Hope_Aur_Hum  Hope Aur Hum   Hope Aur Hum
#
#      is_adult  year_of_release runtime               genres  imdb_rating  \
# 107         0             2018      96  Comedy|Drama|Family          6.4
#
#      imdb_votes                                              story  \
# 107         289  A father obsessed with an old school copying m...
#
#                                                summary tagline  \
# 107  A father obsessed with an old school copying m...     NaN
#
#                                                 actors wins_nominations  \
# 107  Naseeruddin Shah|Kabir Sajid|Virti Vaghani|Son...              NaN
#
#             release_date
# 107  11 May 2018 (India)

# %%
movies.sort_values(['year_of_release','title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','runtime'])
# Out:
#                        title_x     imdb_id  \
# 1601          Maya (2001 film)   tt0299027
# 1594                    Grahan   tt0275381
# 1592       Ehsaas: The Feeling   tt0302524
# 1599   Kuch Khatti Kuch Meethi   tt0271604
# 1586  Bengal Tiger (2001 film)   tt0477574
# ...                        ...         ...
# 36                 Kabir Singh   tt8983202
# 39      Hume Tumse Pyaar Kitna   tt6862542
# 35        Khamoshi (2019 film)   tt8268972
# 48                     Pranaam   tt7228072
# 60          Yaaram (2019 film)  tt11007050
#
#                                             poster_path  \
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# 1594  https://upload.wikimedia.org/wikipedia/en/thum...
# 1592                                                NaN
# 1599  https://upload.wikimedia.org/wikipedia/en/thum...
# 1586  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
batsman=pd.read_csv('batsman_runs_ipl.csv')
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['batsman_run'].rank(ascending=False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
batsman['batsranking']=batsman['batsman_run'].rank(ascending=False)

# %%
batsman
# Out:
#              batter  batsman_run  batsranking
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]

# %% [markdown]
# batsman.sort_values

# %%
batsman.sort_values('batsranking')
# Out:
#            batter  batsman_run  batsranking
# 569       V Kohli         6634          1.0
# 462      S Dhawan         6244          2.0
# 130     DA Warner         5883          3.0
# 430     RG Sharma         5881          4.0
# 493      SK Raina         5536          5.0
# ..            ...          ...          ...
# 600    Yash Dayal            0        594.0
# 595    YA Abdulla            0        594.0
# 57         AS Roy            0        594.0
# 63   Abdur Razzak            0        594.0
# 65     Akash Deep            0        594.0
#
# [605 rows x 3 columns]

# %%
batsman
# Out:
#              batter  batsman_run  batsranking
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]

# %%
#42
#sort_index(series and DataFrame)

# %%
marks={
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}
marks_series=pd.Series(marks)

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index()
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
#set_index is applicable on only DataFrame.
batsman.set_index('batter')
# Out:
#                 batsman_run  batsranking
# batter
# A Ashish Reddy          280        166.5
# A Badoni                161        226.0
# A Chandila                4        535.0
# A Chopra                 53        329.0
# A Choudhary              25        402.5
# ...                     ...          ...
# Yash Dayal                0        594.0
# Yashpal Singh            47        343.0
# Younis Khan               3        547.5
# Yuvraj Singh           2754         27.0
# Z Khan                  117        256.0
#
# [605 rows x 2 columns]

# %%
#reset_index(series+DataFrame) ->Drop parameter
batsman
# Out:
#              batter  batsman_run  batsranking
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]

# %%
batsman.reset_index
# Out:
# <bound method DataFrame.reset_index of              batter  batsman_run  batsranking
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]>

# %%
#how to replace existing index without loosing.
batsman.reset_index
# Out:
# <bound method DataFrame.reset_index of              batter  batsman_run  batsranking
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]>

# %%
#series  to DataFrame using reset_indexing

# %%
movies.sample()
# Out:
#                   title_x    imdb_id  \
# 1148  Banaras (2006 film)  tt0449189
#
#                                             poster_path  \
# 1148  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  title_y  \
# 1148  https://en.wikipedia.org/wiki/Banaras_(2006_film)  Banaras
#
#      original_title  is_adult  year_of_release runtime         genres  \
# 1148        Banaras         0             2006     122  Drama|Musical
#
#       imdb_rating  imdb_votes  \
# 1148          6.2         301
#
#                                                   story  \
# 1148  Shwetambri Nath lives a wealthy lifestyle in t...
#
#                                                 summary              tagline  \
# 1148  A mystic love story... between two people of d...  A mystic love story
#
#                                                  actors wins_nominations  \
# 1148  Urmila Matondkar|Ashmit Patel|Dimple Kapadia|R...              NaN
#
# ...

# %%
movies.set_index('release_date')
# Out:
#                                                        title_x     imdb_id  \
# release_date
# 11 January 2019 (USA)                 Uri: The Surgical Strike   tt8291224
# 11 January 2019 (India)                          Battalion 609   tt9472208
# 11 January 2019 (USA)     The Accidental Prime Minister (film)   tt6986710
# 18 January 2019 (USA)                          Why Cheat India   tt8108208
# 11 January 2019 (India)                        Evening Shadows   tt6028796
# ...                                                        ...         ...
# 7 November 2001 (India)                  Tera Mera Saath Rahen   tt0301250
# 16 November 2001 (India)                  Yeh Zindagi Ka Safar   tt0298607
# NaN                                            Sabse Bada Sukh   tt0069204
# 1 November 2019 (USA)                                    Daaka  tt10833860
# TV Series (2011–2012)                                 Humsafar   tt2403201
#
# ...

# %%
#movies[movies.set_index('release_date')]=movies['is_adult']='0'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5180\2644544383.py in ?()
# ----> 1 movies[movies.set_index('release_date')]=movies['is_adult']='0'
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4298             slc = self.index._convert_slice_indexer(key, kind="getitem")
#    4299             return self._setitem_slice(slc, value)
#    4300
#    4301         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
# -> 4302             self._setitem_frame(key, value)
#    4303         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4304             self._setitem_array(key, value)
#    4305         elif isinstance(value, DataFrame):
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
# ...

# %%
movies.set_index('title_x',inplace=True)

# %%
movies
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace=True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(index={'Uri: The Surgical Strike	':'Uri','Battalion 609	':'Battalion '},inplace=True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique(Series)
Temp=pd.Series([1,23,4,55,6])
Temp.unique()
# Out:
# array([ 1, 23,  4, 55,  6])

# %%
movies['summary'].unique()
# Out:
# array(['Indian army special forces execute a covert operation  avenging the killing of fellow army men at their base by a terrorist group.',
#        'The story of Battalion 609 revolves around a cricket match between the Indian Army and the Pakistan army gone wrong and narrates the tale of the brave soldiers of Battalion 609 putting up a fight with the mighty Taliban.',
#        "Explores Manmohan Singh's tenure as the Prime Minister of India and the kind of control he had over the cabinet and the country.",
#        ...,
#        'Village born Lalloo re-locates to Bombay  and returns a wealthy man. He goes to meet his friend  Shankar alias Bhompu  and together they meet and share tales  mostly about women  sex  and ...                    ',
#        "Shinda tries robbing a bank so he can be wealthy enough to marry the love of his life. He ends up getting caught  but it turns out that he has a much bigger plan in mind  involving one of Punjab's biggest criminals.",
# ...

# %%
movies['summary'].unique()#unique count NAN value
# Out:
# array(['Indian army special forces execute a covert operation  avenging the killing of fellow army men at their base by a terrorist group.',
#        'The story of Battalion 609 revolves around a cricket match between the Indian Army and the Pakistan army gone wrong and narrates the tale of the brave soldiers of Battalion 609 putting up a fight with the mighty Taliban.',
#        "Explores Manmohan Singh's tenure as the Prime Minister of India and the kind of control he had over the cabinet and the country.",
#        ...,
#        'Village born Lalloo re-locates to Bombay  and returns a wealthy man. He goes to meet his friend  Shankar alias Bhompu  and together they meet and share tales  mostly about women  sex  and ...                    ',
#        "Shinda tries robbing a bank so he can be wealthy enough to marry the love of his life. He ends up getting caught  but it turns out that he has a much bigger plan in mind  involving one of Punjab's biggest criminals.",
# ...

# %%
movies['summary'].nunique()# nunique does not count nan value.
# Out:
# 1604

# %%
#isnull(series+DataFrame)

# %%
students['name'][students['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
students['name'][students['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
#notnull(Series+DataFrame),it is compliments of isnull()
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
#hasnans(Series,it tell in particular columns has any missing value or not
students['name'].hasnans
# Out:
# True

# %%
len(students['name'])
# Out:
# 10

# %%
len(students['name'].notnull())
# Out:
# 10

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True   False  False     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False    True   True    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False    True   True    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True   False  False     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
students.nunique()
# Out:
# name       6
# college    6
# branch     7
# cgpa       7
# package    6
# dtype: int64

# %% [markdown]
# how to manage missing value in Datasets.

# %%
#dropna(Series+ DataFrame) -> how parameters -> works like or(it is used to remove all missing value)
#students['name'] =students[students['name'].dropna()]

# %%
students['name']
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3           NaN
# 4    mrityunjay
# 5           NaN
# 6       rishabh
# 7           NaN
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
#dropna on DataFrame it remove thoes rows which has any missing value. 
students.dropna()#default parameter is (how='any')
# Out:
#      name college branch  cgpa  package
# 0  nitish     bit    bio  7.40      4.0
# 1   ankit     iit     it  8.25      5.0
# 2  rupesh     vit     me  5.60      6.0

# %%
students.dropna(how='all')
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.dropna(subset=['name'])#remove based on particular columns.
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 4  mrityunjay     NaN    civ   7.40      6.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 8      aditya     NaN    cse  10.00      NaN

# %%
students.dropna(subset=['name','college'])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    bio  7.40      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit     me  5.60      6.0
# 6  rishabh    ssit    NaN   NaN      8.0

# %%
students.dropna(subset=['name','college'])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    bio  7.40      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit     me  5.60      6.0
# 6  rishabh    ssit    NaN   NaN      8.0

# %%
#fillna(Series+DataFrame)
students['name'].fillna('unknown')
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3       unknown
# 4    mrityunjay
# 5       unknown
# 6       rishabh
# 7       unknown
# 8        aditya
# 9       unknown
# Name: name, dtype: object

# %%
students.fillna('0')
# Out:
#          name college branch  cgpa package
# 0      nitish     bit    bio   7.4     4.0
# 1       ankit     iit     it  8.25     5.0
# 2      rupesh     vit     me   5.6     6.0
# 3           0       0    eee  6.66       0
# 4  mrityunjay       0    civ   7.4     6.0
# 5           0    visi    cse  6.41     7.0
# 6     rishabh    ssit      0     0     8.0
# 7           0       0     ce   9.0     0.0
# 8      aditya       0    cse  10.0       0
# 9           0     git      0     0       0

# %%
students['college'].fillna('unknown')
# Out:
# 0        bit
# 1        iit
# 2        vit
# 3    unknown
# 4    unknown
# 5       visi
# 6       ssit
# 7    unknown
# 8    unknown
# 9        git
# Name: college, dtype: object

# %%
students['package']
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3    NaN
# 4    6.0
# 5    7.0
# 6    8.0
# 7    0.0
# 8    NaN
# 9    NaN
# Name: package, dtype: float64

# %%
students['package'].fillna(students['package'].mean())
# Out:
# 0    4.000000
# 1    5.000000
# 2    6.000000
# 3    5.142857
# 4    6.000000
# 5    7.000000
# 6    8.000000
# 7    0.000000
# 8    5.142857
# 9    5.142857
# Name: package, dtype: float64

# %%
students['name'].fillna(method='bfill')#hidden parameter of fillna and similarliy is ffill
# Out:
# C:\Users\rashi\AppData\Local\Temp\ipykernel_5180\3895938316.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['name'].fillna(method='bfill')#hidden parameter of fillna and similarliy is ffill
# 0        nitish
# 1         ankit
# 2        rupesh
# 3    mrityunjay
# 4    mrityunjay
# 5       rishabh
# 6       rishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
#dropduplicates

# %%
df.duplicated()# it is used to recognised as duplicates values as true.
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
temp=pd.Series([1,1,2,3,46,65,767,23,4])

# %%
temp.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
temp.duplicated().sum()
# Out:
# np.int64(1)

# %%
df['marks'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: marks, dtype: bool

# %%
df['marks'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['marks'].astype('int32')
# Out:
# 0     80
# 1     70
# 2    100
# 3     50
# Name: marks, dtype: int32

# %%
temp.drop_duplicates()#it remove  all duplicates  values.
# Out:
# 0      1
# 2      2
# 3      3
# 4     46
# 5     65
# 6    767
# 7     23
# 8      4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1      1
# 2      2
# 3      3
# 4     46
# 5     65
# 6    767
# 7     23
# 8      4
# dtype: int64

# %%
ipl_matches.sample()
# Out:
#          ID  City        Date Season MatchNumber          Team1  \
# 572  598053  Pune  2013-05-09   2013          56  Pune Warriors
#
#                      Team2                       Venue             TossWinner  \
# 572  Kolkata Knight Riders  Subrata Roy Sahara Stadium  Kolkata Knight Riders
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 572          bat         N  Kolkata Knight Riders  Runs    46.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 572       G Gambhir  ['RV Uthappa', 'AJ Finch', 'Yuvraj Singh', 'UA...
#
#                                           Team2Players    Umpire1   Umpire2
# 572  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'EJG Mo...  Asad Rauf  S Asnani

# %%
# find  the last match played by virat kohli in Delhi.
#ipl_matches([ipl_matches['City']=='Delhi' + ipl_matches['Player_of_Match']=='Kohli']).drop_ascending(keep='last')

# %%
ipl_matches['Player_of_Match']=='Kohli'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: Player_of_Match, Length: 950, dtype: bool

# %%
ipl_matches['all_player']=ipl_matches['Team1']+ ipl_matches['Team2']

# %%
ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_matches['all_player']=ipl_matches['Team1Players']=ipl_matches['Team2Players']

# %%
ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def did_kohli_players(players_list):
    return 'T Kohli' in players_list

# %%
ipl_matches['did_kohli_play']=ipl_matches['all_player'].apply(did_kohli_players)

# %%
ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_matches[(ipl_matches['City']=='Delhi')& (ipl_matches['did_kohli_play']==True)]
# Out:
#          ID   City        Date   Season MatchNumber             Team1  \
# 947  335984  Delhi  2008-04-19  2007/08           3  Delhi Daredevils
#
#                 Team2             Venue        TossWinner TossDecision  ...  \
# 947  Rajasthan Royals  Feroz Shah Kotla  Rajasthan Royals          bat  ...
#
#        WonBy Margin method  Player_of_Match  \
# 947  Wickets    9.0    NaN      MF Maharoof
#
#                                           Team1Players  \
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...
#
#                                           Team2Players    Umpire1  \
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...  Aleem Dar
#
#             Umpire2                                         all_player  \
# 947  GA Pratapkumar  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...
#
#     did_kohli_play
# 947           True
#
# [1 rows x 22 columns]

# %%
ipl_matches['did_kohli_play']==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947     True
# 948    False
# 949    False
# Name: did_kohli_play, Length: 950, dtype: bool

# %%
students.drop_duplicates()
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    bio   7.40      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 7         NaN     NaN     ce   9.00      0.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
temp1=pd.Series([10,2,3,16,45,78,10])
temp1
# Out:
# 0    10
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
temp1.drop(index=[0,6])
# Out:
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# dtype: int64

# %%
students.drop(columns=['college'])
# Out:
#          name branch   cgpa  package
# 0      nitish    bio   7.40      4.0
# 1       ankit     it   8.25      5.0
# 2      rupesh     me   5.60      6.0
# 3         NaN    eee   6.66      NaN
# 4  mrityunjay    civ   7.40      6.0
# 5         NaN    cse   6.41      7.0
# 6     rishabh    NaN    NaN      8.0
# 7         NaN     ce   9.00      0.0
# 8      aditya    cse  10.00      NaN
# 9         NaN    NaN    NaN      NaN

# %%
students.drop(index=[0,7])
# Out:
#          name college branch   cgpa  package
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit     me   5.60      6.0
# 3         NaN     NaN    eee   6.66      NaN
# 4  mrityunjay     NaN    civ   7.40      6.0
# 5         NaN    visi    cse   6.41      7.0
# 6     rishabh    ssit    NaN    NaN      8.0
# 8      aditya     NaN    cse  10.00      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.set_index('name').drop(index=['ankit','aditya'])
# Out:
#            college branch  cgpa  package
# name
# nitish         bit    bio  7.40      4.0
# rupesh         vit     me  5.60      6.0
# NaN            NaN    eee  6.66      NaN
# mrityunjay     NaN    civ  7.40      6.0
# NaN           visi    cse  6.41      7.0
# rishabh       ssit    NaN   NaN      8.0
# NaN            NaN     ce  9.00      0.0
# NaN            git    NaN   NaN      NaN

# %%
#apply(Series+Dataframe)

# %%
points_df=pd.DataFrame({
    '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
    'second point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    
})
points_df
# Out:
#   1st point second point
# 0    (3, 4)      (-3, 4)
# 1   (-6, 5)       (0, 0)
# 2    (0, 0)       (2, 2)
# 3  (-10, 1)     (10, 10)
# 4    (4, 5)       (1, 1)

# %%
def euclidean(row):
    pt_A=row['1st point']
    pt_B=row['second point']
    return ((pt_A[0] - pt_B[1])**2 + (pt_A[1]-pt_B[1])**2)**0.5

# %%
points_df['distance']=points_df.apply(euclidean,axis=1)
